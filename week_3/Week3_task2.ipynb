# %% [markdown]
# # Install Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# # Read Geospatial data

# %%
# Geospatial_Coordinates provided in the instruction
lonlat=pd.read_csv('E:\\Saurav\\LAPPY\\study\\Coursera\\IBM_Data_Science\\project\\IBM_DATA_SCIENCE\\week_3\\Geospatial_Coordinates.csv')

# Toronto table created in task 1
trt=pd.read_csv('E:\\Saurav\\LAPPY\\study\\Coursera\\IBM_Data_Science\\project\\IBM_DATA_SCIENCE\\week_3\\week_3_task_2.csv')

# %%
trt
# Out:
#     PostalCode      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# ..         ...          ...
# 98         M9N         York
# 99         M9P    Etobicoke
# 100        M9R    Etobicoke
# 101        M9V    Etobicoke
# 102        M9W    Etobicoke
#
#                                          Neighborhood2  \
# 0                                       Malvern, Rouge
# 1               Rouge Hill, Port Union, Highland Creek
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# ..                                                 ...
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, St. Phillips, Martin Grove ...
# 101  South Steeles, Silverstone, Humbergate, Jamest...
# ...

# %% [markdown]
# # Merging Data

# %%
# Change the name "Postal Code" in lonlat to "PostalCode"
lonlat.rename(columns={'Postal Code':'PostalCode'},inplace=True)

# Left join
trt_geo=pd.merge(trt,lonlat,how='left',on='PostalCode')
trt_geo.drop(columns='Neighborhood2',inplace=True)

# %% [markdown]
# # Export the table

# %%
# Export trt_geo for the preparation of Task 3
trt_geo.to_csv(r'E:\\Saurav\\LAPPY\\study\\Coursera\\IBM_Data_Science\\project\\IBM_DATA_SCIENCE\\week_3\\week_3_task_3.csv',index=None,header=True)

# %%
trt_geo
# Out:
#     PostalCode      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# ..         ...          ...
# 98         M9N         York
# 99         M9P    Etobicoke
# 100        M9R    Etobicoke
# 101        M9V    Etobicoke
# 102        M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                              Weston  43.706876 -79.518188
# ...

# %%
trt_geo.shape
# Out:
# (103, 5)
